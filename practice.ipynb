# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2
# 히스토, 리사이즈, 컨투어, 정규화처리

# %%
import os
import torch
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
data_dir = '../data/osteoarthritis/auto_test/0/'
img_name = os.listdir(data_dir)[41]
img_path = os.path.join(data_dir, img_name)
img_original = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

plt.imshow(img_original, cmap='gray')
plt.title('KNEE')
plt.show()

# %%
data_dir = '../data/osteoarthritis/auto_test/4/'
img_name = os.listdir(data_dir)[41]
img_path = os.path.join(data_dir, img_name)
img_4g = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

plt.imshow(img_4g, cmap='gray')
plt.title('G4 KNEE')
plt.show()

# %%
# resize
def resize_image(img, size=(128,128)):
    return cv2.resize(img, size)

resized_image = resize_image(img_4g)
plt.imshow(resized_image, cmap='gray')
plt.title('knee resize')
plt.show()

# %%
def normalize_img(img):
    return cv2.normalize(img, None, 0 ,255, cv2.NORM_MINMAX)

normalized_img = normalize_img(img_4g)
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_4g, cmap='gray')
plt.title('Original Image')
plt.subplot(1, 2, 2)
plt.imshow(normalized_img, cmap='gray')
plt.title('Normalized_image')
plt.show()

# %%
ret, thresh = cv2.threshold(img_4g, 127,255,0)
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,
                                       cv2.CHAIN_APPROX_SIMPLE)

contours_img = cv2.drawContours(img_4g.copy(), contours,
                                -1, (0,255,0), 2)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_original, cmap='gray')
plt.title('Original Image')
plt.subplot(1, 2, 2)
plt.imshow(contours_img, cmap='gray')
plt.title('contours_img')
plt.show()

# %%
src = cv2.imread('../data/osteoarthritis/auto_test/4/', cv2.IMREAD_GRAYSCALE)
ret, thresh = cv2.threshold(img_4g, 127, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
draw_img = cv2.drawContours(img_4g.copy(), contours, -1, (0, 255, 0), 3)
draw_img = cv2.adaptiveThreshold(img_4g,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,15,2)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_original, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(draw_img, cmap='gray')
plt.title('contours_img')
plt.show()

# %%
src = cv2.imread('../data/osteoarthritis/auto_test/0/', cv2.IMREAD_GRAYSCALE)
ret, thresh = cv2.threshold(img_original, 127, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
draw_img = cv2.drawContours(img_original.copy(), contours, -1, (0, 255, 0), 3)
draw_img = cv2.adaptiveThreshold(img_original,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,15,2)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(draw_img, cmap='gray')
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.imshow(thresh, cmap='gray')
plt.title('contours_img')
plt.show()

# %%
contours, hierarchy
# Out:
# ((), None)

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt 

img = cv2.imread('images/dave.png',0)
# img = cv2.medianBlur(img,5)

ret, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)



th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
cv2.THRESH_BINARY,15,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,15,2)

titles = ['Original','Global','Mean','Gaussian']

images = [img,th1,th2,th3]

for i in range(4):
	plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
	plt.title(titles[i])
	plt.xticks([]),plt.yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 10
#       6 # img = cv2.medianBlur(img,5)
#       8 ret, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# ---> 10 th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#      11 cv2.THRESH_BINARY,15,2)
#      13 titles = ['Original','Global','Mean','Gaussian']
#      15 images = [img,th1,th2]
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:617: error: (-215:Assertion failed) !_src.empty() in function 'cv::GaussianBlur'
